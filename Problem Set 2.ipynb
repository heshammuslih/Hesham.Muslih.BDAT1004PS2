# %% [markdown]
# # Problem Set 2
# # Student: Hesham Muslih
# # Student Number: 200468751

# %% [markdown]
# # Question 1
# Consider the following Python module:

# %%
a = 0
def b():
    global a
    a = c(a)
def c(a):
    return a + 2

b()
b()
b()
print(a)
# Out:
# 6

# %% [markdown]
# Explain the answer: funtion "b" is using the global variable "a" and assigned to it the returing value from function "c" which receive any value and return that value after adding 2 to it. in other words each call for the function "b" is going increase the value of variable "a" 2. as you can see I added the print the value of variable "a" after each call.
# a = a + (2 * Number of calling function "b")

# %% [markdown]
# # Question 2
# Function fileLength(), given to you, takes the name of a file as input and returns the length of the file:
# >>> fileLength('midterm.py') 284
# >>> fileLength('idterm.py')
# Traceback (most recent call last): File "<pyshell#34>", line 1, in <module>
#     fileLength('idterm.py') File "/Users/me/midterm.py", line 3, in fileLength infile = open(filename)
#     FileNotFoundError: [Errno 2] No such file or directory: 'idterm.py'
# As shown above, if the file cannot be found by the interpreter or if it cannot be read as a text file, an exception will be raised. Modify function fileLength() so that a friendly message is printed instead: >>> fileLength('midterm.py') 358 >>> fileLength('idterm.py') File idterm.py not found.

# %%
def file_length(file_name):
    try:
        file = open(file_name)
        contents = file.read()
        file.close()
        print(len(contents))
    except:
        print('File ' + file_name + ' not found.')

file_length('SampleFile.txt')
file_length('SampleFileerwwwefeahjydtr.txt')
# Out:
# 9
# File SampleFileerwwwefeahjydtr.txt not found.

# %% [markdown]
# # Question 3
# Write a class named Marsupial that can be used as shown below:<br>
#     m = Marsupial() <br>
#     m.put_in_pouch('doll') <br>
#     m.put_in_pouch('firetruck') <br>
#     m.put_in_pouch('kitten') <br>
#     m.pouch_contents() <br>
#     ['doll', 'firetruck', 'kitten']<br>
# Now write a class named Kangaroo as a subclass of Marsupial that inherits all the attributes of Marsupial and also:<br>
# a. extends the Marsupial __init__ constructor to take, as input, the coordinates x and y of the Kangaroo object,<br>
# b. supports method jump that takes number values dx and dy as input and moves the kangaroo by dx units along the x-axis and by dy units along the y-axis, and<br>
# c. overloads the __str__ operator so it behaves as shown below.<br>
# k = Kangaroo(0,0) <br>
# print(k) I am a Kangaroo located at coordinates (0,0) <br>
# k.put_in_pouch('doll') <br>
# k.put_in_pouch('firetruck') <br>
# k.put_in_pouch('kitten') <br>
# k.pouch_contents() <br>
# ['doll', 'firetruck', 'kitten'] <br>
# k.jump(1,0) <br>
# k.jump(1,0) <br>
# k.jump(1,0) <br>
# print(k) I am a Kangaroo located at coordinates (3,0)<br>

# %%
class Marsupial:
    pouch = []
    def put_in_pouch(self,item):
        self.pouch.append(item)
    def pouch_contents(self):
        print(self.pouch)
        
class Kangaroo(Marsupial):
    def __init__(self,xCoord,yCoord):
        self.x = xCoord
        self.y = yCoord
    def __str__(self):
        return 'print(k) I am a Kangaroo located at coordinates ({}, {})'.format(self.x, self.y)
    def jump(self,xCoord,yCoord):
        self.x = self.x + xCoord
        self.y = self.y + yCoord
        
k = Kangaroo(0,0)
print(k) 
k.put_in_pouch('doll')
k.put_in_pouch('firetruck')
k.put_in_pouch('kitten')
k.pouch_contents()

k.jump(1,0)
k.jump(1,0)
k.jump(1,0)
print(k)
# Out:
# print(k) I am a Kangaroo located at coordinates (0, 0)
# ['doll', 'firetruck', 'kitten']
# print(k) I am a Kangaroo located at coordinates (3, 0)

# %% [markdown]
# # Question 4
# Write function collatz() that takes a positive integer x as input and prints the Collatz sequence starting at x. A Collatz <br>sequence is obtained by repeatedly applying this rule to the previous number x in the sequence:<br>
# x = 𝑥/2 𝑖𝑓 𝑥 𝑖𝑠 𝑒𝑣𝑒𝑛 <br>
# x = 3𝑥+1 𝑖𝑓 𝑥 𝑖𝑠 𝑜𝑑𝑑<br>
# Your function should stop when the sequence gets to number 1. Your implementation must be recursive, without any loops.<br>

# %%
def collatz(x):
    print(x)
    if x > 1:
        if (x % 2) == 0:
            #In this case x is even
            collatz(x/2)
        else:
            #In this case x is odd
            collatz((x * 3) + 1)
        
collatz(10)
# Out:
# 10
# 5.0
# 16.0
# 8.0
# 4.0
# 2.0
# 1.0

# %% [markdown]
# # Question 5
# Write a recursive method binary() that takes a non-negative integer n and prints the binary representation of integer n.

# %%
def binary(n):
    converted = ''
    if n > 0:
        #The below variable will "floor division" n on 2 and then send it again recursivly to binary(n) unless the number reach zero
        numberAfterDevidedOnTwo = n // 2
        converted = converted + str(binary(numberAfterDevidedOnTwo))
        #The below variable will always take Zero for even number, or 1 for odd number and concatination with the end of converted binary.
        remainingAfterModeOnTwo = n % 2
        #Since the remainingAfterModeOnTwo is 0 or 1 then we will concatenate it with end converted number to right side of the number.
        converted = converted + str(remainingAfterModeOnTwo)
    return converted
print(binary(1))
print(binary(5))
print(binary(8))
print(binary(10))
print(binary(16))
print(binary(32))
print(binary(64))
print(binary(65))
# Out:
# 1
# 101
# 1000
# 1010
# 10000
# 100000
# 1000000
# 1000001

# %% [markdown]
# # Question 6
# Implement a class named HeadingParser that can be used to parse an HTML document, and retrieve and print all the headings in the document. You should implement your class as a subclass of HTMLParser, defined in Standard Library module html.parser. When fed a string containing HTML code, your class should print the headings, one per line and in the order in which they appear in the document. Each heading should be indented as follows: an h1 heading should have
# indentation 0, and h2 heading should have indentation 1, etc. Test your implementation using w3c.html.
# >infile = open('w3c.html')
# >content = infile.read()
# >infile.close()
# >hp = HeadingParser()
# >hp.feed(content)
# W3C Mission
#     Principles

# %%
from html.parser import HTMLParser
class HeadingParser(HTMLParser):
    headingTag = ''
    def handle_starttag(self, tag, attrs):
        self.headingTag = tag.lower()
        if self.headingTag not in ['h1','h2','h3','h4','h5','h6']:
            self.headingTag = ''
       
    def handle_data(self,data):
        if self.headingTag != '' and data.strip() != '':
            print('\t' * (int(self.headingTag[1:])-1) + data)
                          
infile = open('w3c.html')
content = infile.read()
infile.close()
hp = HeadingParser()
hp.feed(content)
# Out:
# W3C Mission
# 	Principles

# %% [markdown]
# # Question 7
# Implement recursive function webdir() that takes as input: a URL (as a string) and non-negative integers depth and indent. Your function should visit every web page reachable from the starting URL web page in depth clicks or less, and print each web page's URL. As shown below, indentation, specified by indent, should be used to indicate the depth of a URL.<br>
# webdir('http://reed.cs.depaul.edu/lperkovic/csc242/test1.html', 2, 0) http://reed.cs.depaul.edu/lperkovic/csc242/test1.html http://reed.cs.depaul.edu/lperkovic/csc242/test2.html http://reed.cs.depaul.edu/lperkovic/csc242/test4.html http://reed.cs.depaul.edu/lperkovic/csc242/test3.html http://reed.cs.depaul.edu/lperkovic/csc242/test4.html

# %%
from urllib.parse import urljoin
from html.parser import HTMLParser
from urllib.request import urlopen
class Collector(HTMLParser):
    'collects hyperlink URLs into a list'

    def __init__(self, url):
        'initializes parser, the url, and a list'
        HTMLParser.__init__(self)
        self.url = url
        self.links = []

    
    def handle_starttag(self, tag, attrs):
        'collects hyperlink URLs in their absolute format'
        if tag == 'a':
            for attr in attrs:
                if attr[0] == 'href':
                    # construct absolute URL
                    absolute = urljoin(self.url, attr[1])
                    if absolute[:4] == 'http': # collect HTTP URLs
                        self.links.append(absolute)
                        
    def getLinks(self):
        'returns hyperlinks URLs in their absolute format'
        return self.links

visitedLinks = set()
def webdir(url,depth,indent):
    try:
        global visitedLinks
        visitedLinks.add(url)
        
        resource = urlopen(url)
        content = resource.read().decode()
        collector = Collector(url)
        collector.feed(content)
        links = collector.getLinks()
        for link in links:
            print('\t' * indent + link)
            if (depth > 0 and link not in visitedLinks):
                webdir(link,depth - 1, indent + 1)
    except:
        print('error page is not accessable: ' + url)

webdir('https://www.w3.org/Consortium/mission.html',1,0)
# Out:
# https://www.w3.org/
# 	https://www.w3.org/
# 	https://www.w3.org/standards/
# 	https://www.w3.org/participate/
# 	https://www.w3.org/Consortium/membership
# 	https://www.w3.org/Consortium/
# 	https://www.w3.org/Consortium/mission.html#principles
# 	https://www.w3.org/WAI/
# 	https://www.w3.org/International/
# 	https://www.w3.org/Security/
# 	https://www.w3.org/Privacy/
# 	https://www.w3.org/standards/
# 	https://www.w3.org/auto/
# 	https://www.w3.org/tv/
# 	https://www.w3.org/publishing/
# 	https://www.w3.org/Payments/
# 	https://www.w3.org/2013/data/
# 	https://www.w3.org/Telco/
# 	https://www.w3.org/WoT/
# 	https://www.w3.org/groups/
# 	https://www.w3.org/Consortium/cepc/
# 	https://www.w3.org/Guide/
# 	https://www.w3.org/community/groups/
# 	https://www.w3.org/Help/Account/
# 	https://www.w3.org/participate/
# 	https://www.w3.org/developers/
# 	https://www.w3.org/api/
# 	https://validator.w3.org/
# 	https://www.w3.org/2009/cheatsheet/
# 	https://www.w3.org/Status.html
# ...

# %% [markdown]
# # Question 8
# Write SQL queries on the below database table that return:<br>
# a) All the temperature data.<br>
# b) All the cities, but without repetition.<br>
# c) All the records for India.<br>
# d) All the Fall records.<br>
# e) The city, country, and season for which the average rainfall is between 200 and 400 millimeters.<br>
# f) The city and country for which the average Fall temperature is above 20 degrees, in increasing temperature order.<br>
# g) The total annual rainfall for Cairo.<br>
# h) The total rainfall for each season.<br>

# %%
 # !pip install ipython-sql

# %%
# %%capture
# %load_ext sql
# %sql sqlite:///chinook.db

# %%
# %%sql
# CREATE TABLE WeatherInfo
# (
#   City text,
#   Country text,
#   Season text,
#   Temperature_c float,
#   Rainfall_mm float
# )
# Out:
#  * sqlite:///chinook.db
# Done.
# Done.
# []

# %%
# %%sql
# Delete from WeatherInfo;
# INSERT INTO WeatherInfo VALUES ('Mumbai', 'India', 'Winter', 24.8, 5.9);
# INSERT INTO WeatherInfo VALUES ('Mumbai', 'India', 'Spring', 28.4, 16.2);
# INSERT INTO WeatherInfo VALUES ('Mumbai', 'India', 'Summer', 27.9, 1549.4);
# INSERT INTO WeatherInfo VALUES ('Mumbai', 'India', 'Fall', 27.6, 346.0);
#
# INSERT INTO WeatherInfo VALUES ('London', 'United Kingdom', 'Winter', 4.2, 207.7);
# INSERT INTO WeatherInfo VALUES ('London', 'United Kingdom', 'Spring', 8.3, 169.6);
# INSERT INTO WeatherInfo VALUES ('London', 'United Kingdom', 'Summer', 15.7, 157.0);
# INSERT INTO WeatherInfo VALUES ('London', 'United Kingdom', 'Fall', 10.4, 218.5);
#
# INSERT INTO WeatherInfo VALUES ('Cairo', 'Egypt', 'Winter', 13.6, 16.5);
# INSERT INTO WeatherInfo VALUES ('Cairo', 'Egypt', 'Spring', 20.7, 6.5);
# INSERT INTO WeatherInfo VALUES ('Cairo', 'Egypt', 'Summer', 27.7, 0.1);
# INSERT INTO WeatherInfo VALUES ('Cairo', 'Egypt', 'Fall', 22.2, 4.5);
# Out:
#  * sqlite:///chinook.db
# 12 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# []

# %%
# %%sql
# select Temperature_c from weatherinfo;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(24.8,),
#  (28.4,),
#  (27.9,),
#  (27.6,),
#  (4.2,),
#  (8.3,),
#  (15.7,),
#  (10.4,),
#  (13.6,),
#  (20.7,),
#  (27.7,),
#  (22.2,)]

# %%
# %%sql
# select City,Country,Season,Temperature_c,Rainfall_mm from weatherinfo;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Mumbai', 'India', 'Winter', 24.8, 5.9),
#  ('Mumbai', 'India', 'Spring', 28.4, 16.2),
#  ('Mumbai', 'India', 'Summer', 27.9, 1549.4),
#  ('Mumbai', 'India', 'Fall', 27.6, 346.0),
#  ('London', 'United Kingdom', 'Winter', 4.2, 207.7),
#  ('London', 'United Kingdom', 'Spring', 8.3, 169.6),
#  ('London', 'United Kingdom', 'Summer', 15.7, 157.0),
#  ('London', 'United Kingdom', 'Fall', 10.4, 218.5),
#  ('Cairo', 'Egypt', 'Winter', 13.6, 16.5),
#  ('Cairo', 'Egypt', 'Spring', 20.7, 6.5),
#  ('Cairo', 'Egypt', 'Summer', 27.7, 0.1),
#  ('Cairo', 'Egypt', 'Fall', 22.2, 4.5)]

# %%
# %%sql
# select distinct City from weatherinfo;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Mumbai',), ('London',), ('Cairo',)]

# %%
# %%sql
# select * from weatherinfo where Country = 'India';
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Mumbai', 'India', 'Winter', 24.8, 5.9),
#  ('Mumbai', 'India', 'Spring', 28.4, 16.2),
#  ('Mumbai', 'India', 'Summer', 27.9, 1549.4),
#  ('Mumbai', 'India', 'Fall', 27.6, 346.0)]

# %%
# %%sql
# select * from weatherinfo where Season = 'Fall';
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Mumbai', 'India', 'Fall', 27.6, 346.0),
#  ('London', 'United Kingdom', 'Fall', 10.4, 218.5),
#  ('Cairo', 'Egypt', 'Fall', 22.2, 4.5)]

# %%
# %%sql
# select City,Country,Season from weatherinfo where Rainfall_mm between 200 and 400;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Mumbai', 'India', 'Fall'),
#  ('London', 'United Kingdom', 'Winter'),
#  ('London', 'United Kingdom', 'Fall')]

# %%
# %%sql
# select City,Country from weatherinfo where Season = 'Fall' and Temperature_c > 20 order by Temperature_c;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Cairo', 'Egypt'), ('Mumbai', 'India')]

# %%
# %%sql
# select sum(Rainfall_mm) from weatherinfo where City = 'Cairo'
# Out:
#  * sqlite:///chinook.db
# Done.
# [(27.6,)]

# %%
# %%sql
# select sum(Rainfall_mm),season from weatherinfo group by season
# Out:
#  * sqlite:///chinook.db
# Done.
# [(569.0, 'Fall'),
#  (192.29999999999998, 'Spring'),
#  (1706.5, 'Summer'),
#  (230.1, 'Winter')]

# %% [markdown]
# # Question 9
# Suppose list words is defined as follows:
# >words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
wordsInUpperCase = []
wordsInUpperCase = [word.upper() for word in words]
wordsInLowerCase = [word.lower() for word in words]
wordsLenght = [len(word) for word in words]
wordsFourOrMoreChar = [word for word in words if len(word) > 3]
wordsListofListCombination = [[word.upper(),word.lower(),len(word)] for word in words]
print('-List of words in upper case:')
print(wordsInUpperCase)
print('-List of words in lower case:')
print(wordsInLowerCase)
print('-List of words length:')
print(wordsLenght)
print('-List of words containing 4 or more characters:')
print(wordsFourOrMoreChar)
print('-List of list words combination:')
print(wordsListofListCombination)
# Out:
# -List of words in upper case:
# ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']
# -List of words in lower case:
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
# -List of words length:
# [3, 5, 5, 3, 5, 4, 3, 4, 3]
# -List of words containing 4 or more characters:
# ['quick', 'brown', 'jumps', 'over', 'lazy']
# -List of list words combination:
# [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]]
